# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandaAdame/Probabilidad-y-estadistica/blob/main/Practica0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# #Probabilidad y estadistica
# ##Unidad 1
# ##Grupo: **2Z**
# ###Practica 0. Introduccion a Python
# Alumno: Perla Fernanda Adame Salazar
#
# Docente: Dr. José Gabriel Rodríguez Rivas

# %%
x = 10 #No es necesario declarar la variable de algun tipo
print(x) #Sirve para imprimir
# Out:
# 10

# %%
print (type(x)) #Sirve para saber el tipo de variable
# Out:
# <class 'int'>

# %%
x = "Hola Hola"
print(x)
print (type(x))
# Out:
# Hola Hola
# <class 'str'>

# %%
a = 12
b = 25
if a > b: #No se utilizan llavez
  print ("a es mayor que b") #es importante dejar los espacios ya que actuan como la separacion (llaves)
else:
  print ("b es mayor que a")
# Out:
# b es mayor que a

# %%
for i in range(10): #solo es necesario escribir el nombre de la variable y el rango
  print(i)
  print("Hola", i)
print ("Fuera del for") #Los espacios son importantes ya que actuan como llaves
# Out:
# 0
# Hola 0
# 1
# Hola 1
# 2
# Hola 2
# 3
# Hola 3
# 4
# Hola 4
# 5
# Hola 5
# 6
# Hola 6
# 7
# Hola 7
# 8
# Hola 8
# 9
# Hola 9
# Fuera del for

# %%
# esto es un comentario
#en el texto los # actuan como el h1 en html (indican el tamaño del encabezado)
# Para agregar una imagen solo se debe copiar y pegar en el apartado texto
# Encerrar palabras en ** las volvera negritas en el apartado de texto
# La flecha sube el apartado
# cerrar el lapiz tachado en el texto guarda los cambios
