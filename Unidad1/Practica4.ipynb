# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandaAdame/Probabilidad-y-estadistica/blob/main/Unidad1/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# #Unidad 1
# ##Práctica 4: Tablas de frecuencias
# Facilitador: Dr. José Gabriel Rodríguez Rivas
#
# Alumno: Perla Fernanda Adame Salazar

# %%
import random
edades = []
for i in range(100):
 numero_aleatorio = random.randint(18, 70)
 edades.append(numero_aleatorio)
print(edades)
# Out:
# [65, 18, 32, 24, 66, 44, 41, 27, 20, 45, 31, 50, 39, 22, 30, 56, 61, 51, 44, 57, 38, 28, 65, 53, 18, 69, 52, 47, 30, 64, 33, 35, 62, 20, 55, 64, 35, 45, 63, 35, 27, 46, 62, 44, 64, 36, 70, 53, 55, 32, 66, 57, 64, 54, 40, 67, 28, 37, 53, 21, 44, 45, 18, 23, 53, 62, 48, 25, 62, 32, 24, 24, 48, 67, 63, 39, 69, 50, 55, 55, 63, 64, 18, 36, 70, 23, 32, 20, 66, 28, 60, 45, 64, 18, 28, 45, 18, 67, 27, 20]

# %%
import pandas as pd
#Crear Dataframe de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    65
# 1    18
# 2    32
# 3    24
# 4    66

# %%
#Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

#Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribucion de frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de frecuencias:
#     Edad  Frecuencia
# 1     18           6
# 4     20           4
# 31    21           1
# 34    22           1
# 20    23           2
# 14    24           3
# 28    25           1
# 10    27           3
# 7     28           4
# 23    30           2
# 30    31           1
# 9     32           4
# 40    33           1
# 15    35           3
# 18    36           2
# 32    37           1
# 26    38           1
# 25    39           2
# 33    40           1
# 29    41           1
# 8     44           4
# 2     45           5
# 36    46           1
# 41    47           1
# 16    48           2
# 24    50           2
# 39    51           1
# 35    52           1
# 3     53           4
# 27    54           1
# 6     55           4
# 37    56           1
# 22    57           2
# 42    60           1
# 38    61           1
# 5     62           4
# 12    63           3
# 0     64           6
# 21    65           2
# 13    66           3
# 11    67           3
# 19    69           2
# 17    70           2

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 1     18           6           0.06
# 4     20           4           0.04
# 31    21           1           0.01
# 34    22           1           0.01
# 20    23           2           0.02
# 14    24           3           0.03
# 28    25           1           0.01
# 10    27           3           0.03
# 7     28           4           0.04
# 23    30           2           0.02
# 30    31           1           0.01
# 9     32           4           0.04
# 40    33           1           0.01
# 15    35           3           0.03
# 18    36           2           0.02
# 32    37           1           0.01
# 26    38           1           0.01
# 25    39           2           0.02
# 33    40           1           0.01
# 29    41           1           0.01
# 8     44           4           0.04
# 2     45           5           0.05
# 36    46           1           0.01
# 41    47           1           0.01
# 16    48           2           0.02
# 24    50           2           0.02
# 39    51           1           0.01
# 35    52           1           0.01
# 3     53           4           0.04
# 27    54           1           0.01
# 6     55           4           0.04
# 37    56           1           0.01
# 22    57           2           0.02
# 42    60           1           0.01
# 38    61           1           0.01
# 5     62           4           0.04
# 12    63           3           0.03
# 0     64           6           0.06
# 21    65           2           0.02
# 13    66           3           0.03
# 11    67           3           0.03
# 19    69           2           0.02
# 17    70           2           0.02

# %%
tabla_frecuencias['Frec Porcentual1'] = tabla_frecuencias ['Frecuencia'] / 100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual1
# 1     18           6           0.06               6.0
# 4     20           4           0.04               4.0
# 31    21           1           0.01               1.0
# 34    22           1           0.01               1.0
# 20    23           2           0.02               2.0
# 14    24           3           0.03               3.0
# 28    25           1           0.01               1.0
# 10    27           3           0.03               3.0
# 7     28           4           0.04               4.0
# 23    30           2           0.02               2.0
# 30    31           1           0.01               1.0
# 9     32           4           0.04               4.0
# 40    33           1           0.01               1.0
# 15    35           3           0.03               3.0
# 18    36           2           0.02               2.0
# 32    37           1           0.01               1.0
# 26    38           1           0.01               1.0
# 25    39           2           0.02               2.0
# 33    40           1           0.01               1.0
# 29    41           1           0.01               1.0
# 8     44           4           0.04               4.0
# 2     45           5           0.05               5.0
# 36    46           1           0.01               1.0
# 41    47           1           0.01               1.0
# 16    48           2           0.02               2.0
# 24    50           2           0.02               2.0
# 39    51           1           0.01               1.0
# 35    52           1           0.01               1.0
# 3     53           4           0.04               4.0
# 27    54           1           0.01               1.0
# 6     55           4           0.04               4.0
# 37    56           1           0.01               1.0
# 22    57           2           0.02               2.0
# 42    60           1           0.01               1.0
# 38    61           1           0.01               1.0
# 5     62           4           0.04               4.0
# 12    63           3           0.03               3.0
# 0     64           6           0.06               6.0
# 21    65           2           0.02               2.0
# 13    66           3           0.03               3.0
# 11    67           3           0.03               3.0
# 19    69           2           0.02               2.0
# 17    70           2           0.02               2.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias ['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual1  Frec Acumulada
# 1     18           6           0.06               6.0               6
# 4     20           4           0.04               4.0              10
# 31    21           1           0.01               1.0              11
# 34    22           1           0.01               1.0              12
# 20    23           2           0.02               2.0              14
# 14    24           3           0.03               3.0              17
# 28    25           1           0.01               1.0              18
# 10    27           3           0.03               3.0              21
# 7     28           4           0.04               4.0              25
# 23    30           2           0.02               2.0              27
# 30    31           1           0.01               1.0              28
# 9     32           4           0.04               4.0              32
# 40    33           1           0.01               1.0              33
# 15    35           3           0.03               3.0              36
# 18    36           2           0.02               2.0              38
# 32    37           1           0.01               1.0              39
# 26    38           1           0.01               1.0              40
# 25    39           2           0.02               2.0              42
# 33    40           1           0.01               1.0              43
# 29    41           1           0.01               1.0              44
# 8     44           4           0.04               4.0              48
# 2     45           5           0.05               5.0              53
# 36    46           1           0.01               1.0              54
# 41    47           1           0.01               1.0              55
# 16    48           2           0.02               2.0              57
# 24    50           2           0.02               2.0              59
# 39    51           1           0.01               1.0              60
# 35    52           1           0.01               1.0              61
# 3     53           4           0.04               4.0              65
# 27    54           1           0.01               1.0              66
# 6     55           4           0.04               4.0              70
# 37    56           1           0.01               1.0              71
# 22    57           2           0.02               2.0              73
# 42    60           1           0.01               1.0              74
# 38    61           1           0.01               1.0              75
# 5     62           4           0.04               4.0              79
# 12    63           3           0.03               3.0              82
# 0     64           6           0.06               6.0              88
# 21    65           2           0.02               2.0              90
# 13    66           3           0.03               3.0              93
# 11    67           3           0.03               3.0              96
# 19    69           2           0.02               2.0              98
# 17    70           2           0.02               2.0             100

# %%
import math

# %%
print(edades)
# Out:
# [65, 18, 32, 24, 66, 44, 41, 27, 20, 45, 31, 50, 39, 22, 30, 56, 61, 51, 44, 57, 38, 28, 65, 53, 18, 69, 52, 47, 30, 64, 33, 35, 62, 20, 55, 64, 35, 45, 63, 35, 27, 46, 62, 44, 64, 36, 70, 53, 55, 32, 66, 57, 64, 54, 40, 67, 28, 37, 53, 21, 44, 45, 18, 23, 53, 62, 48, 25, 62, 32, 24, 24, 48, 67, 63, 39, 69, 50, 55, 55, 63, 64, 18, 36, 70, 23, 32, 20, 66, 28, 60, 45, 64, 18, 28, 45, 18, 67, 27, 20]

# %%
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     65
# 1     18
# 2     32
# 3     24
# 4     66
# ..   ...
# 95    45
# 96    18
# 97    67
# 98    27
# 99    20
#
# [100 rows x 1 columns]

# %%
n = len(edades)
K = int(1 + math.log2(n))
print("Valor de n = ", n, " \nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0    (62.571, 70.0]    21
# 1  (17.947, 25.429]    18
# 2  (47.714, 55.143]    15
# 3  (25.429, 32.857]    14
# 4  (40.286, 47.714]    12
# 5  (32.857, 40.286]    11
# 6  (55.143, 62.571]     9

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    18
# 3  (25.429, 32.857]    14
# 5  (32.857, 40.286]    11
# 4  (40.286, 47.714]    12
# 2  (47.714, 55.143]    15
# 6  (55.143, 62.571]     9
# 0    (62.571, 70.0]    21

# %%
tabla_frecuencia ['Frec Rel'] =tabla_frecuencia['Frec']/n
tabla_frecuencia ['Frec Porc'] =tabla_frecuencia['Frec']/n*100
tabla_frecuencia ['Frec Ac'] =tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia ['Frec Rel Ac'] =tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia ['Frec Porc Ac'] =tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.947, 25.429]    18      0.18       18.0       18         0.18
# 3  (25.429, 32.857]    14      0.14       14.0       32         0.32
# 5  (32.857, 40.286]    11      0.11       11.0       43         0.43
# 4  (40.286, 47.714]    12      0.12       12.0       55         0.55
# 2  (47.714, 55.143]    15      0.15       15.0       70         0.70
# 6  (55.143, 62.571]     9      0.09        9.0       79         0.79
# 0    (62.571, 70.0]    21      0.21       21.0      100         1.00
#
#    Frec Porc Ac
# 1          18.0
# 3          32.0
# 5          43.0
# 4          55.0
# 2          70.0
# 6          79.0
# 0         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha =0.5, bins=20)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=K, alpha=0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #Práctica 5
# ##Diagramas de cajas y bigotes

# %%
edades2 = []
for i in range(100):
 numero_aleatorio = random.randint(18, 70)
 edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [60, 34, 56, 44, 49, 69, 23, 67, 28, 38, 49, 40, 37, 46, 68, 24, 32, 44, 27, 20, 51, 62, 54, 31, 26, 56, 42, 53, 24, 50, 39, 34, 39, 30, 43, 68, 53, 66, 61, 40, 54, 46, 51, 38, 41, 69, 51, 44, 31, 51, 37, 36, 41, 27, 48, 52, 70, 67, 53, 31, 52, 56, 56, 45, 40, 57, 67, 68, 27, 31, 30, 64, 28, 33, 56, 58, 30, 42, 48, 68, 44, 29, 32, 35, 38, 23, 19, 47, 61, 58, 67, 59, 33, 43, 64, 23, 35, 60, 29, 45]

# %%
fig, (ax1, ax2)= plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                      vert=True, #vertical box aligment
                      patch_artist=True) #fill with color
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2,
                     vert=True, #vertical box aligment
                      patch_artist=True) #fill with color
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
#Agregar una edad más a la lista de edades2
edades2.append(130)

# %%
fig, (ax1, ax2)= plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                      vert=True, #vertical box aligment
                      patch_artist=True) #fill with color
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2,
                     vert=True, #vertical box aligment
                      patch_artist=True) #fill with color
ax2.set_title('Edades Encuesta 2')
plt.show()
