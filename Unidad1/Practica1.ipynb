# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandaAdame/Probabilidad-y-estadistica/blob/main/Unidad1/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# #**Probabilidad y estadistica**
# ##Unidad 1
# ###Practica 1. Estadistica descriptiva básica e histogramas
#
# Facilitador: Dr. José Gabriel Rodríguez Rivas
#
# Alumno: Perla Fernanda Adame Salazar

# %%
from statistics import * #libreria que contiene funciones para calcular estadisticas matematicas, correrla antes

# %% [markdown]
# Ejemplo 1: Registro de calificaciones de 12 alumnos

# %%
#Lista de calificaciones del grupo de probabilidad y estadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
type(grupoa)
# Out:
# list

# %%
#Sacar la media de las calificaciones con una formula
promedio = sum(grupoa) / len(grupoa) #len de longitud
print (promedio)
# Out:
# 75.33333333333333

# %%
#utilizar la funcion mean que esta en la libreria statistics para sacar el promedio
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
#Determinar el valor de la mediana con la funcion median
mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
#Determinar el valor de la moda con la funcion mode
moda =mode(grupoa)
print(moda)
# Out:
# 70

# %%
#En caso de que exista más de una moda, se puede emplear la funcion multimode
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
#Tiempo que tardaron 10 alumnos para correr los 100 metros
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
#usamos la funcion mean para determinar el tiempo promedio
print("El tiempo promedio de los corredires es=>", mean(tiempos100mts)) #se concatenan con una coma
# Out:
# El tiempo promedio de los corredires es=> 17.322

# %%
#Moda
moda = mode(tiempos100mts)
print("La moda de los tiempos es=>", moda)
# Out:
# La moda de los tiempos es=> 15.1

# %%
multimodas = multimode(tiempos100mts)
print("La moda de los tiempos es=>", multimodas)
# Out:
# La moda de los tiempos es=> [15.1, 17.2]

# %%
#Libreria para generar números aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [74.58, 56.79, 99.78, 60.01, 59.52, 80.62, 74.23, 79.96, 55.64, 82.24, 77.24, 50.28, 62.3, 50.21, 67.78, 83.61, 50.78, 62.92, 62.71, 97.61, 88.03, 97.39, 98.3, 58.87, 70.9, 71.79, 82.04, 94.39, 54.99, 51.83, 87.5, 51.85, 78.9, 62.93, 59.79, 68.01, 56.08, 83.06, 63.22, 84.02, 59.87, 80.57, 70.0, 53.89, 70.93, 71.56, 60.27, 67.09, 88.99, 57.14, 88.33, 88.37, 60.25, 52.35, 90.06, 59.82, 93.71, 86.08, 92.61, 64.93, 77.28, 76.76, 50.65, 56.4, 86.76, 52.38, 98.89, 79.48, 57.47, 96.38, 80.14, 87.61, 84.74, 86.52, 60.22, 65.3, 89.86, 99.15, 78.66, 68.11, 82.0, 62.27, 55.72, 77.01, 84.1, 80.25, 73.84, 89.49, 88.22, 92.87, 51.45, 97.43, 50.5, 86.41, 55.75, 68.32, 52.66, 61.6, 90.65, 59.4]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [79.18, 56.67, 89.83, 59.77, 59.1, 90.65, 63.41, 52.01, 97.04, 76.65, 64.62, 91.61, 81.87, 74.61, 79.77, 77.57, 66.17, 73.63, 75.42, 96.3, 90.19, 90.88, 83.35, 56.95, 62.94, 91.73, 71.7, 95.91, 95.89, 53.76, 97.44, 86.76, 99.85, 77.36, 57.9, 85.64, 88.09, 79.44, 68.1, 65.43, 91.98, 56.28, 86.19, 97.48, 95.77, 57.79, 75.37, 98.41, 76.64, 60.86, 61.13, 59.87, 63.37, 81.89, 61.67, 52.86, 90.69, 99.17, 60.67, 93.58, 76.36, 66.56, 76.26, 57.35, 81.77, 70.0, 93.15, 89.92, 87.0, 79.11, 86.09, 78.26, 74.64, 82.73, 88.01, 66.43, 95.69, 50.37, 51.33, 97.48, 72.32, 63.8, 66.68, 86.32, 98.33, 76.09, 75.52, 64.49, 78.17, 72.91, 99.85, 76.59, 75.04, 76.48, 88.22, 72.26, 90.3, 99.37, 84.36, 52.79]

# %%
#libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("valores de la fabrica 1")
print("La media es =", media1)
print("la mediana es =", mediana1)
print("la moda es =", moda1)
# Out:
# valores de la fabrica 1
# La media es = 73.0222
# la mediana es = 72.815
# la moda es = 74.58

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("valores de la fabrica 2")
print("La media es =", media2)
print("la mediana es =", mediana2)
print("la moda es =", moda2)
# Out:
# valores de la fabrica 2
# La media es = 77.4526
# la mediana es = 77.005
# la moda es = 99.85

# %%
#generar 2 sublot de 1 renglón por 2 columnas para desplegar los 2 histogramas
#una al lado de la otra
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
